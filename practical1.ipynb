# %% [markdown]
# <a href="https://colab.research.google.com/github/aniketkanade25-dev/Simple_Python_Program/blob/main/practical1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### 1. WAP to compute factorial of a given number

# %%
def factorial(n):
    if n == 0:
        return 1
    else:
        res = 1
        for i in range(1, n + 1):
            res *= i
        return res

# Test the function with user input
try:
    num_input = int(input("Enter a number to compute its factorial: "))
    print(f"The factorial of {num_input} is {factorial(num_input)}")
except ValueError:
    print("Invalid input. Please enter an integer.")
# Out:
# Enter a number to compute its factorial: 5
# The factorial of 5 is 120

# %% [markdown]
# ### 2. WAP to display table for a given number

# %%
def display_multiplication_table(num):
    print(f"Multiplication Table for {num}:")
    for i in range(1, 11):
        print(f"{num} x {i} = {num * i}")

# Test the function with user input
try:
    num_input = int(input("Enter a number to display its multiplication table: "))
    display_multiplication_table(num_input)
except ValueError:
    print("Invalid input. Please enter an integer.")
# Out:
# Enter a number to display its multiplication table: 5
# Multiplication Table for 5:
# 5 x 1 = 5
# 5 x 2 = 10
# 5 x 3 = 15
# 5 x 4 = 20
# 5 x 5 = 25
# 5 x 6 = 30
# 5 x 7 = 35
# 5 x 8 = 40
# 5 x 9 = 45
# 5 x 10 = 50

# %% [markdown]
# ### 3. WAP to identify the given number is odd or even

# %%
def check_odd_even(num):
    if num % 2 == 0:
        print(f"{num} is an even number.")
    else:
        print(f"{num} is an odd number.")

# Test the function with user input
try:
    num_input = int(input("Enter a number to check if it's odd or even: "))
    check_odd_even(num_input)
except ValueError:
    print("Invalid input. Please enter an integer.")
# Out:
# Enter a number to check if it's odd or even: 25
# 25 is an odd number.

# %% [markdown]
# ### 4. WAP to identify the entered number is palindrome or not.

# %%
def check_palindrome(num):
    # Convert number to string to easily reverse it
    s_num = str(num)
    reversed_s_num = s_num[::-1]

    if s_num == reversed_s_num:
        print(f"{num} is a palindrome.")
    else:
        print(f"{num} is not a palindrome.")

# Test the function with user input for numbers
try:
    num_input = int(input("Enter a number to check if it's a palindrome: "))
    check_palindrome(num_input)
except ValueError:
    print("Invalid input. Please enter an integer.")

# Also works for strings if input is handled as such
def check_string_palindrome(text):
    clean_text = text.lower().replace(" ", "") # Optional: make case-insensitive and ignore spaces
    if clean_text == clean_text[::-1]:
        print(f"'{text}' is a palindrome.")
    else:
        print(f"'{text}' is not a palindrome.")

# Test with user input for strings
text_input = input("Enter a word or phrase to check if it's a palindrome: ")
check_string_palindrome(text_input)
# Out:
# Enter a number to check if it's a palindrome: madam
# Invalid input. Please enter an integer.
# Enter a word or phrase to check if it's a palindrome: madam
# 'madam' is a palindrome.

# %% [markdown]
# ### 5. Develop an Expert System that provides simple decision-making.

# %%
def simple_expert_system():
    print("Welcome to the Simple Activity Advisor Expert System!")
    print("Please answer a few questions to get an activity suggestion.")

    while True:
        weather = input("What's the weather like today? (sunny/cloudy/rainy): ").lower()
        if weather in ['sunny', 'cloudy', 'rainy']:
            break
        else:
            print("Invalid weather input. Please choose from sunny, cloudy, or rainy.")

    while True:
        mood = input("How are you feeling today? (happy/neutral/sad): ").lower()
        if mood in ['happy', 'neutral', 'sad']:
            break
        else:
            print("Invalid mood input. Please choose from happy, neutral, or sad.")

    print("\n--- Decision Making ---")

    # Decision rules
    if weather == 'sunny':
        if mood == 'happy':
            print("Suggestion: Go for a picnic or play outdoor sports!")
        elif mood == 'neutral':
            print("Suggestion: Take a pleasant walk in the park.")
        elif mood == 'sad':
            print("Suggestion: Get some sun; it might lift your spirits! Maybe a gentle walk.")
    elif weather == 'cloudy':
        if mood == 'happy':
            print("Suggestion: Visit a museum or go to a coffee shop.")
        elif mood == 'neutral':
            print("Suggestion: Read a book or watch a movie.")
        elif mood == 'sad':
            print("Suggestion: Listen to some comforting music or try a new indoor hobby.")
    elif weather == 'rainy':
        if mood == 'happy':
            print("Suggestion: Have a cozy movie marathon or bake something delicious.")
        elif mood == 'neutral':
            print("Suggestion: Work on a puzzle or learn a new skill online.")
        elif mood == 'sad':
            print("Suggestion: Enjoy a warm beverage and reflect, or journal your thoughts.")
    else:
        print("Sorry, I couldn't make a suggestion based on the provided information.")

    print("\nThank you for using the Simple Activity Advisor!")

# Run the expert system (this function is interactive and takes user input)
simple_expert_system()
# Out:
# Welcome to the Simple Activity Advisor Expert System!
# Please answer a few questions to get an activity suggestion.
# What's the weather like today? (sunny/cloudy/rainy): sunny
# How are you feeling today? (happy/neutral/sad): happy
#
# --- Decision Making ---
# Suggestion: Go for a picnic or play outdoor sports!
#
# Thank you for using the Simple Activity Advisor!
